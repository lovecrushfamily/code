# %% [markdown]
# ## Starry night

# %%
import cv2

# %%
starryNight = cv2.imread('Starry Night.png')
starryNight
# Out:
# array([[[ 89,  64,  54],
#         [ 58,  31,  21],
#         [ 63,  31,  25],
#         ...,
#         [110, 143, 159],
#         [118, 151, 167],
#         [136, 169, 185]],
#
#        [[ 87,  64,  56],
#         [ 69,  43,  36],
#         [ 79,  50,  43],
#         ...,
#         [144, 177, 193],
#         [123, 156, 172],
#         [125, 158, 174]],
#
#        [[ 59,  37,  31],
#         [ 44,  22,  16],
#         [ 57,  31,  25],
#         ...,
#         [160, 193, 209],
#         [140, 173, 189],
#         [117, 150, 166]],
#
#        ...,
#
#        [[ 93, 128, 142],
#         [ 61,  96, 109],
#         [101, 135, 148],
#         ...,
#         [ 51,  75,  87],
#         [ 87, 116, 130],
#         [ 92, 129, 143]],
#
#        [[ 84, 124, 142],
#         [ 85, 126, 141],
#         [ 99, 138, 153],
#         ...,
#         [109, 140, 155],
#         [125, 160, 174],
#         [129, 168, 183]],
#
#        [[118, 153, 173],
#         [103, 139, 157],
#         [ 79, 112, 131],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(starryNight)
plt.show()
